# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
import os

# %%
ls
# Out:
#  Volume in drive C is Blade
#  Volume Serial Number is 3C82-E70A
#
#  Directory of C:\Users\Razer\Desktop\pix2pix-tensorflow\Untitled Folder
#
# 11-08-2018  13:33    <DIR>          .
# 11-08-2018  13:33    <DIR>          ..
# 11-08-2018  12:10    <DIR>          .ipynb_checkpoints
# 11-08-2018  13:33           132,384 postprocess.ipynb
#                1 File(s)        132,384 bytes
#                3 Dir(s)  44,579,573,760 bytes free

# %%
PATH = '../niti/test_out/images/'

# %%
ops = []

# %%
for each in os.listdir(PATH):
    if each.endswith('outputs.png'):
        ops.append(PATH + each)

# %%
x = cv2.imread(ops[0])

# %%
y = np.zeros((256*14, 256*40, 3))

# %%
for i in range(14):
    for j in range(40):
        patch = np.array(img[i*PATCH_SIZE:(i+1)*PATCH_SIZE, j*PATCH_SIZE:(j+1)*PATCH_SIZE,:])
        cv2.imwrite(OUT+'{0}_{1}.jpg'.format(i,j), patch)

# %%
plt.imshow(y[...,::-1])

# %%
base = np.zeros((256*15, 256*41, 3))

# %%
for each in ops:
    indices = each[24:-12].split('_')
    i, j = int(indices[0]), int(indices[1])
    print(i, j)
    patch = cv2.imread(each)
    base[i*256:(i+1)*256, j*256:(j+1)*256, :] = patch

# %%
base.shape
# Out:
# (3840, 10496, 3)

# %%
cv2.imwrite('kmeans5.png', res2)
# Out:
# True

# %%
img = cv2.imread('stitch.png')
Z = img.reshape((-1,3))
Z = np.float32(Z)

criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 5
ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)

center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))

# %%
bar = np.zeros((50, 600, 3), dtype = "uint8")
startX = 0

for (percent, color) in zip(counts/np.mean(counts), center):
    endX = startX + (percent * 60)
    cv2.rectangle(bar, (int(startX), 0), (int(endX), 50),
        color.astype("uint8").tolist(), -1)
    startX = endX

# %%
plt.figure(figsize=(15,15))
plt.title('Output of the neural network')
plt.imshow(cv2.imread('stitch.png')[...,::-1])
plt.show()

# %%
plt.figure(figsize=(15,15))
plt.title('K Means clustering of map')
plt.imshow(res2[...,::-1])
plt.show()

# %%
plt.title('Relative area')
plt.imshow(bar[...,::-1])
plt.show()

# %%
gray = cv2.cvtColor(res2.astype('uint8'), cv2.COLOR_BGR2GRAY)
counts, bins, bars = plt.hist(gray.ravel(),256,[0,256])
plt.title('Histogram of pixels for gray scale picture')
plt.show()

# %%
color = []
for i, j in enumerate(counts):
    if j != 0:
        color.append(i)

# %%
selected = bins[color]

# %%
total = gray.shape[0]*gray.shape[1]
